# %% [markdown]
# # Introduction: Business Problem

# %% [markdown]
# An established America coffee shop company, “Coffee on the go”, plans to open a number of takeaway shops (no-sitting) in London. Given their takeaway business model, the company needs to determine where the new outlets should be optimally located within the different boroughs in Central London, within Zone 1 (the area served by the underground system in London is defined by zones and zone 1 is the most central).
#
# The main variable taken into account to pinpoint the ideal locations is to identify the areas in Central London with the highest number of potential customers “street traffic” (people walking in a given area). From a previous consumer survey, we know that customers of takeaway coffee shops usually purchase a coffee in the morning on their way to the workplace. Since the majority of workers in central London commute to their workplace by underground, takeaway coffee shops should be located ideally close or within minimum walking distance to underground stations.
#
# The goal is to locate those shops in such a way that all the city underground stations are within minimal walking distance. Since there are lots of coffee shops in central London, we will try to detect locations that are not already crowded with existing outlets. We are also particularly interested in areas with no coffee shops in vicinity. We would also prefer locations close to underground stations that have a high “street traffic”, assuming that first two conditions are met.
# We implement a K-Median model to get the optimal location of future shops. We will use this technique to generate a few most promising neighbourhood locations based on the above criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ***

# %% [markdown]
# # Data

# %% [markdown]
# We decided to use a grid of locations centred around underground stations to define our potential locations. Based on the definition of our problem, factors that will be appraised to take our decision are:
# * Identification of underground stations locations in central London.
# * Estimate the number of commuters exiting each station on average per day.
# * Number of and distance to existing coffee shops in the stations neighbourhood.
#
# The Following data sources will be needed to extract/generate the required information:
# * The list of tube stations and their exact locations are obtained from Transport for London (TfL) web-site (https://tfl.gov.uk/info-for/open-data-users).
# * The information about numbers of passenger exiting each London Underground station (or number of exits) are obtained as well from Tfl; exits are defined as number of passengers passing gates or ticket barriers going from the platforms to the street.
# * The number of coffee shops and their location in every underground station proximity will be obtained using the Foursquare API
# * Coordinate of central London will be obtained using standard geocoding library functions.
#
# ## Additional data insight
# ### Stations geo-locations
# It can be surprisingly hard to find a nicely structured dataset of stations and geo locations. Luckily some TfL libraries had some CSVs buried in it; otherwise the following web-sites provide and alternative source of structured data on stations geo location:
# * https://www.doogal.co.uk/london_stations.php
# * https://commons.wikimedia.org/wiki/London_Underground_geographic_maps/CSV
#
# ### Passenger counts data
# On the Transport for London (TfL) web-site https://tfl.gov.uk/info-for/open-data-users, under the Network statistics tab is possible to access passenger counts data. TfL collects information about passenger numbers entering and exiting London Underground stations, largely based on the Underground ticketing system gate data. Counts data is obtained during the autumn of each year and does not necessarily reflect whole-year annual demand. The data is adjusted to remove the effect of abnormal circumstances that may affect demand such as industrial action. We use data collected by TfL based on survey data up to 2017 and reconciled to Autumn 2017 counts. The data provides the number of exits for each underground station mapped by the survey; the data number of exits are reported by Time Period, namely: {Early, AM peak, Midday, PM Peak, Evening, Late, Total day}. Exits are defined as number of passengers passing gates or ticket barriers going from the platforms to the street. The exits number by time period for each station are provided alongside the unique station number, the Borough in which the station is located and the station name itself.

# %% [markdown]
# ***

# %% [markdown]
# # The London Tube

# %% [markdown]
# I found it suprisingly hard to find a nicely structured dataset of stations and connections between them. Luckily this library had some CSVs buried in it with just what I was looking for. So i yanked them out and opened them in pandas.
# https://www.doogal.co.uk/london_stations.php
# https://commons.wikimedia.org/wiki/London_Underground_geographic_maps/CSV
# crowding.data.tfl.gov.uk

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Total number of tube stations locations  266
#     ID  Latitude  Longitude     Station Name  Station Number  Zone  \
# 0    1   51.5028    -0.2801       Acton Town           500.0   3.0
# 1    2   51.5143    -0.0755          Aldgate           502.0   1.0
# 2    3   51.5154    -0.0726     Aldgate East           503.0   1.0
# 4    5   51.5407    -0.2997         Alperton           505.0   4.0
# 5    7   51.5322    -0.1058            Angel           507.0   1.0
# 6    8   51.5653    -0.1353          Archway           508.0   2.5
# 7    9   51.6164    -0.1331      Arnos Grove           509.0   4.0
# 8   10   51.5586    -0.1059          Arsenal           510.0   2.0
# 9   11   51.5226    -0.1571     Baker Street           511.0   1.0
# 10  12   51.4431    -0.1525           Balham           512.0   3.0
# 11  13   51.5133    -0.0886  Bank / Monument           513.0   1.0
# 12  14   51.5204    -0.0979         Barbican           501.0   1.0
# 13  15   51.5396     0.0810          Barking           514.0   4.0
# 14  16   51.5856     0.0887      Barkingside           515.0   5.0
# 15  17   51.4905    -0.2139     Barons Court           516.0   2.0
# 16  18   51.5121    -0.1879        Bayswater           517.0   1.0
# 19  21   51.5403     0.1270        Becontree           518.0   5.0
# 20  22   51.5504    -0.1642     Belsize Park           519.0   2.0
# 21  24   51.5270    -0.0549    Bethnal Green           520.0   2.0
# 22  25   51.5120    -0.1031      Blackfriars           521.0   1.0
#
#     total_lines  rail
# 0             2     0
# 1             2     0
# 2             2     0
# 4             1     0
# 5             1     0
# 6             1     0
# 7             1     0
# 8             1     0
# 9             5     0
# 10            1     1
# 11            4     0
# 12            3     0
# 13            2     1
# 14            1     0
# 15            2     0
# 16            2     0
# 19            1     0
# 20            1     0
# 21            1     0
# 22            2     0

# %% [markdown]
# On the Trasport for London (TfL) web-site https://tfl.gov.uk/info-for/open-data-users, under the Network statistics tab is possible to access passenger counts data. TfL collects information about passenger numbers entering and exiting London Underground stations, largely based on the Underground ticketing system gate data. Counts data is obtained during the autumn of each year and does not necessarily reflect whole-year annual demand. The data is adjusted to remove the effect of abnormal circumstances that may affect demand such as industrial action.
#
# We use data collected by TfL based on survey data up to 2017 and reconciled to Autumn 2017 counts. The data provides the number of exits for each underground station mapped by the survey; the data number of exits are reported by Time Period, namely:
# {Early, AM peak, Midday, PM Peak, Evening, Late, Total day}. Exits are defined as number of passengers passing gates or ticket barriers going from the platforms to the street. The exits number by time period for each station are provided alongside the unique station number, the Borough in which the station is located and the station name itself.

# %%
body = client_de32eb85ef4840c1b273bc5319d51693.get_object(Bucket='capstoneprojectapplieddatascience-donotdelete-pr-frb4mhxgtaehr5',Key='Total exits by borough-time of day.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

peakExit = pd.read_csv(body)
peakExit.columns = ['Borough','Station Number','Station Name','Time Period','Number exiting']

ExitPerStation = peakExit.loc[~peakExit['Station Number'].isin(['NaN'])]
ExitPerStation.reset_index(drop=True, inplace=True)
ExitPerStation.head(58)
# Out:
#                            Borough  Station Number          Station Name  \
# 0   Barking                                  514.0  Barking
# 1   Barking                                  514.0  Barking
# 2   Barking                                  514.0  Barking
# 3   Barking                                  514.0  Barking
# 4   Barking                                  514.0  Barking
# 5   Barking                                  514.0  Barking
# 6   Barking                                  514.0  Barking
# 7   Barking                                  518.0  Becontree
# 8   Barking                                  518.0  Becontree
# 9   Barking                                  518.0  Becontree
# 10  Barking                                  518.0  Becontree
# 11  Barking                                  518.0  Becontree
# 12  Barking                                  518.0  Becontree
# 13  Barking                                  518.0  Becontree
# 14  Barking                                  555.0  Dagenham East
# 15  Barking                                  555.0  Dagenham East
# 16  Barking                                  555.0  Dagenham East
# 17  Barking                                  555.0  Dagenham East
# 18  Barking                                  555.0  Dagenham East
# 19  Barking                                  555.0  Dagenham East
# 20  Barking                                  555.0  Dagenham East
# 21  Barking                                  556.0  Dagenham Heathway
# 22  Barking                                  556.0  Dagenham Heathway
# 23  Barking                                  556.0  Dagenham Heathway
# 24  Barking                                  556.0  Dagenham Heathway
# 25  Barking                                  556.0  Dagenham Heathway
# 26  Barking                                  556.0  Dagenham Heathway
# 27  Barking                                  556.0  Dagenham Heathway
# 28  Barking                                  738.0  Upney
# 29  Barking                                  738.0  Upney
# 30  Barking                                  738.0  Upney
# 31  Barking                                  738.0  Upney
# 32  Barking                                  738.0  Upney
# 33  Barking                                  738.0  Upney
# 34  Barking                                  738.0  Upney
# 35  Barnet                                   529.0  Brent Cross
# 36  Barnet                                   529.0  Brent Cross
# 37  Barnet                                   529.0  Brent Cross
# 38  Barnet                                   529.0  Brent Cross
# 39  Barnet                                   529.0  Brent Cross
# 40  Barnet                                   529.0  Brent Cross
# 41  Barnet                                   529.0  Brent Cross
# 42  Barnet                                   532.0  Burnt Oak
# 43  Barnet                                   532.0  Burnt Oak
# 44  Barnet                                   532.0  Burnt Oak
# 45  Barnet                                   532.0  Burnt Oak
# 46  Barnet                                   532.0  Burnt Oak
# 47  Barnet                                   532.0  Burnt Oak
# 48  Barnet                                   532.0  Burnt Oak
# 49  Barnet                                   551.0  Colindale
# 50  Barnet                                   551.0  Colindale
# 51  Barnet                                   551.0  Colindale
# 52  Barnet                                   551.0  Colindale
# 53  Barnet                                   551.0  Colindale
# 54  Barnet                                   551.0  Colindale
# 55  Barnet                                   551.0  Colindale
# 56  Barnet                                   565.0  East Finchley
# 57  Barnet                                   565.0  East Finchley
#
#    Time Period  Number exiting
# 0   Early                 1139
# 1   AM peak               5990
# 2   Midday                6226
# 3   PM Peak              11325
# 4   Evening               4925
# 5   Late                  1903
# 6    Total day           31507
# 7   Early                   89
# 8   AM peak                461
# 9   Midday                1253
# 10  PM Peak               2565
# 11  Evening               1148
# 12  Late                   517
# 13   Total day            6035
# 14  Early                   65
# 15  AM peak                603
# 16  Midday                 900
# 17  PM Peak               1946
# 18  Evening                998
# 19  Late                   337
# 20   Total day            4850
# 21  Early                  140
# 22  AM peak               1225
# 23  Midday                2481
# 24  PM Peak               3883
# 25  Evening               1901
# 26  Late                   637
# 27   Total day           10268
# 28  Early                   53
# 29  AM peak                487
# 30  Midday                 840
# 31  PM Peak               1841
# 32  Evening                642
# 33  Late                   194
# 34   Total day            4056
# 35  Early                   56
# 36  AM peak                505
# 37  Midday                 985
# 38  PM Peak               1415
# 39  Evening                646
# 40  Late                   363
# 41   Total day            3970
# 42  Early                   55
# 43  AM peak                713
# 44  Midday                1436
# 45  PM Peak               3147
# 46  Evening               1275
# 47  Late                   555
# 48   Total day            7180
# 49  Early                  225
# 50  AM peak               1921
# 51  Midday                1914
# 52  PM Peak               4738
# 53  Evening               2155
# 54  Late                  1112
# 55   Total day           12064
# 56  Early                   72
# 57  AM peak               1380

# %%
# This table aggregates the number of exits per day by Borough

TotalForBorough = peakExit.loc[peakExit['Station Number'].isin(['NaN'])]
TotalForBorough.reset_index(drop=True, inplace=True)
TotalForBorough = TotalForBorough.drop(columns=['Station Number','Station Name'], axis = 1)
TotalForBorough = TotalForBorough.loc[TotalForBorough['Time Period'].isin([' Total day'])]
TotalForBorough.reset_index(drop=True, inplace=True)
print('Total number of Borough on survey', len(TotalForBorough))
TotalForBorough.sort_values('Number exiting', ascending=False).head(10)
# Out:
# Total number of Borough on survey 32
#                            Borough Time Period  Number exiting
# 31  Westminster                      Total day         1029767
# 4   Camden                           Total day          513541
# 5   City of London                   Total day          425289
# 20  Lambeth                          Total day          306749
# 27  Southwark                        Total day          259328
# 28  Tower Hamlets                    Total day          251313
# 23  Newham                           Total day          248361
# 19  Kensington & Chelsea             Total day          233535
# 18  Islington                        Total day          225838
# 11  Hammersmith & Fulham             Total day          183301

# %%
stationsData = stations.merge(ExitPerStation, left_on='Station Number', right_on='Station Number',suffixes=('_left', '_right'))
stationsDataZone_1 = stationsData.loc[stationsData['Zone']==1]
# reset index, because we droped rows
stationsDataZone_1.reset_index(drop=True, inplace=True)
stationsDataZone_1_Total = stationsDataZone_1.loc[stationsDataZone_1['Time Period'].isin([' Total day'])]
stationsDataZone_1_Total.reset_index(drop=True, inplace=True)
stationsDataZone_1_Total.rename(columns={'Station Name_left': 'Station Name'}, inplace=True)
stationsDataZone_1_Total.drop(columns=['total_lines','rail','Station Name_right'], axis = 1,inplace=True)
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print('Total number of Stations on survey', len(stationsDataZone_1_Total))
stationsDataZone_1_Total.sort_values('Number exiting', ascending=False).head(200)
# Out:
# Total number of Stations on survey 59
#      ID  Latitude  Longitude              Station Name  Station Number  Zone  \
# 28  145   51.5308    -0.1238  King's Cross St. Pancras           625.0   1.0
# 56  279   51.5036    -0.1143                  Waterloo           747.0   1.0
# 40  192   51.5150    -0.1415             Oxford Circus           669.0   1.0
# 4    13   51.5133    -0.0886           Bank / Monument           513.0   1.0
# 5   166   51.5108    -0.0863           Bank / Monument           513.0   1.0
# 54  273   51.4965    -0.1447                  Victoria           741.0   1.0
# 33  156   51.5178    -0.0823          Liverpool Street           634.0   1.0
# 34  157   51.5052    -0.0864             London Bridge           635.0   1.0
# 41  193   51.5154    -0.1755                Paddington           670.0   1.0
# 24  107   51.5067    -0.1428                Green Park           590.0   1.0
# 18   89   51.5282    -0.1337                    Euston           574.0   1.0
# 52  259   51.5165    -0.1310      Tottenham Court Road           728.0   1.0
# 9    28   51.5142    -0.1494               Bond Street           524.0   1.0
# 42  197   51.5098    -0.1342         Piccadilly Circus           674.0   1.0
# 26  126   51.5174    -0.1200                   Holborn           607.0   1.0
# 38  167   51.5186    -0.0886                  Moorgate           645.0   1.0
# 48  236   51.4941    -0.1738          South Kensington           708.0   1.0
# 32  151   51.5113    -0.1281          Leicester Square           631.0   1.0
# 3    11   51.5226    -0.1571              Baker Street           511.0   1.0
# 39  188   51.5263    -0.0873                Old Street           665.0   1.0
# 20   92   51.5203    -0.1053                Farringdon           577.0   1.0
# 57  285   51.5010    -0.1254               Westminster           761.0   1.0
# 17   87   51.5074    -0.1223                Embankment           542.0   1.0
# 55  277   51.5247    -0.1384             Warren Street           745.0   1.0
# 12   48   51.5185    -0.1111             Chancery Lane           541.0   1.0
# 53  263   51.5098    -0.0766                Tower Hill           731.0   1.0
# 2     7   51.5322    -0.1058                     Angel           507.0   1.0
# 13   49   51.5080    -0.1247             Charing Cross           718.0   1.0
# 50  250   51.5146    -0.0973                St. Paul's           697.0   1.0
# 58  233   51.5010    -0.1052                 Southwark           784.0   1.0
# 47  229   51.4924    -0.1565             Sloane Square           702.0   1.0
# 8    25   51.5120    -0.1031               Blackfriars           521.0   1.0
# 49  248   51.4994    -0.1335          St. James's Park           695.0   1.0
# 14   60   51.5129    -0.1243             Covent Garden           553.0   1.0
# 19   90   51.5260    -0.1359             Euston Square           575.0   1.0
# 29  146   51.5015    -0.1607             Knightsbridge           626.0   1.0
# 1     3   51.5154    -0.0726              Aldgate East           503.0   1.0
# 37  163   51.5225    -0.1631                Marylebone           641.0   1.0
# 21   99   51.4945    -0.1829           Gloucester Road           583.0   1.0
# 25  122   51.5009    -0.1925    High Street Kensington           605.0   1.0
# 6    14   51.5204    -0.0979                  Barbican           501.0   1.0
# 36  162   51.5136    -0.1586               Marble Arch           640.0   1.0
# 43  198   51.4893    -0.1334                   Pimlico           776.0   1.0
# 46  223   51.5230    -0.1244            Russell Square           694.0   1.0
# 51  255   51.5111    -0.1141                    Temple           724.0   1.0
# 0     2   51.5143    -0.0755                   Aldgate           502.0   1.0
# 11   44   51.5113    -0.0904             Cannon Street           536.0   1.0
# 23  104   51.5238    -0.1439     Great Portland Street           588.0   1.0
# 22  102   51.5205    -0.1347             Goodge Street           586.0   1.0
# 44  208   51.5107    -0.1877                 Queensway           681.0   1.0
# 35  161   51.5122    -0.0940             Mansion House           639.0   1.0
# 16   83   51.5203    -0.1700          Edgware Road (C)           569.0   1.0
# 31  149   51.5119    -0.1756            Lancaster Gate           629.0   1.0
# 10   29   51.5011    -0.0943                   Borough           525.0   1.0
# 27  133   51.5027    -0.1527          Hyde Park Corner           614.0   1.0
# 15   82   51.5199    -0.1679          Edgware Road (B)           774.0   1.0
# 45  212   51.5234    -0.1466             Regent's Park           685.0   1.0
# 7    18   51.5121    -0.1879                 Bayswater           517.0   1.0
# 30  148   51.4991    -0.1115             Lambeth North           628.0   1.0
#
#                            Borough Time Period  Number exiting
# 28  Camden                           Total day          147949
# 56  Lambeth                          Total day          147683
# 40  Westminster                      Total day          138502
# 4   City of London                   Total day          136749
# 5   City of London                   Total day          136749
# 54  Westminster                      Total day          127176
# 33  City of London                   Total day          113087
# 34  Southwark                        Total day          108319
# 41  Westminster                      Total day           81691
# 24  Westminster                      Total day           69611
# 18  Camden                           Total day           64272
# 52  Westminster                      Total day           63613
# 9   Westminster                      Total day           61940
# 42  Westminster                      Total day           57840
# 26  Camden                           Total day           57171
# 38  City of London                   Total day           56123
# 48  Kensington & Chelsea             Total day           50662
# 32  Westminster                      Total day           47945
# 3   Westminster                      Total day           45436
# 39  Hackney                          Total day           42022
# 20  Islington                        Total day           40671
# 57  Westminster                      Total day           40204
# 17  Westminster                      Total day           35515
# 55  Camden                           Total day           34513
# 12  Camden                           Total day           33382
# 53  Tower Hamlets                    Total day           31881
# 2   Islington                        Total day           30631
# 13  Westminster                      Total day           30423
# 50  City of London                   Total day           29932
# 58  Southwark                        Total day           28717
# 47  Kensington & Chelsea             Total day           27657
# 8   City of London                   Total day           25489
# 49  Westminster                      Total day           25461
# 14  Westminster                      Total day           24711
# 19  Camden                           Total day           24211
# 29  Kensington & Chelsea             Total day           23486
# 1   Tower Hamlets                    Total day           23122
# 37  Westminster                      Total day           22220
# 21  Kensington & Chelsea             Total day           20619
# 25  Kensington & Chelsea             Total day           20350
# 6   City of London                   Total day           20336
# 36  Westminster                      Total day           20318
# 43  Westminster                      Total day           17389
# 46  Camden                           Total day           16876
# 51  Westminster                      Total day           16482
# 0   City of London                   Total day           16167
# 11  City of London                   Total day           15265
# 23  Westminster                      Total day           13831
# 22  Camden                           Total day           12931
# 44  Westminster                      Total day           12396
# 35  City of London                   Total day           12140
# 16  Westminster                      Total day           11286
# 31  Westminster                      Total day            9284
# 10  Southwark                        Total day            9246
# 27  Westminster                      Total day            8198
# 15  Westminster                      Total day            7624
# 45  Westminster                      Total day            6316
# 7   Westminster                      Total day            6280
# 30  Lambeth                          Total day            4935

# %% [markdown]
# # Explore the neighborhoods around tube stations in London

# %%
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# convert an address into latitude and longitude values
address = 'London'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of London are 51.5073219, -0.1276474.

# %%
# create map of London using latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
print('Folium installed')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          2.2.2-py35_1      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.0.2s-h7b6447c_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed

# %%
map_london = folium.Map(location=[latitude, longitude], zoom_start=13)
# add markers to map
for lat, lng, borough, neighborhood in zip(stationsDataZone_1_Total['Latitude'], stationsDataZone_1_Total['Longitude'], stationsDataZone_1_Total['Borough'], stationsDataZone_1_Total['Station Name']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Use Foursquare API 
CLIENT_ID = 'REMOVED'# your Foursquare ID
CLIENT_SECRET = 'REMOVED'# # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# Search for a specific venue category

# %%
search_query = 'Coffee'
radius = 500
LIMIT = 100
print(search_query + ' .... OK!')
# Out:
# Coffee .... OK!

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import requests # library to handle requests
from pandas.io.json import json_normalize

# %%
#column_names = ['name','categories','address','cc','city','country','crossStreet','distance','formattedAddress','labeledLatLngs','lat','lng','neighborhood','postalCode','state','id']
#CoffeeShop = pd.DataFrame(columns=column_names)
CoffeeShop = []
for lat, lng, borough, station, exits in zip(stationsDataZone_1_Total['Latitude'], stationsDataZone_1_Total['Longitude'], stationsDataZone_1_Total['Borough'], stationsDataZone_1_Total['Station Name'],stationsDataZone_1_Total['Number exiting']):
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, lat, lng, VERSION, search_query, radius, LIMIT)
    results = requests.get(url).json()
    # assign relevant part of JSON to venues
    venues = results['response']['venues']
    # tranform venues into a dataframe
    dataframe = json_normalize(venues)
    # keep only columns that include venue name, and anything that is associated with location
    filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
    dataframe_filtered = dataframe.loc[:, filtered_columns]
    # filter the category for each row
    dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
    # clean column names by keeping only last term
    dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
    dataframe_filtered['Borough']= borough
    dataframe_filtered['Station Name']= station
    dataframe_filtered['Number exiting']= exits
    CoffeeShop.append(dataframe_filtered)

# %%
CoffeeShop_data = pd.concat(CoffeeShop, axis=0)
CoffeeShop_data.reset_index(drop=True, inplace=True)
CoffeeShop_data.drop(columns=['cc','country','crossStreet','formattedAddress','id','labeledLatLngs','state','neighborhood','city'], axis = 1,inplace=True)

# %% [markdown]
# ### Let's see how many coffee shops have been returned for each tube station given the radius of 500 meters and the venue limit of 100:

# %%
print('Total number of Coffee Shops within 500 meters radius from a given station', len(CoffeeShop_data))
CoffeeShop_data.head(200)
# Out:
# Total number of Coffee Shops within 500 meters radius from a given station 1473
#                             Borough  Number exiting     Station Name  \
# 0    City of London                           16167          Aldgate
# 1    City of London                           16167          Aldgate
# 2    City of London                           16167          Aldgate
# 3    City of London                           16167          Aldgate
# 4    City of London                           16167          Aldgate
# 5    City of London                           16167          Aldgate
# 6    City of London                           16167          Aldgate
# 7    City of London                           16167          Aldgate
# 8    City of London                           16167          Aldgate
# 9    City of London                           16167          Aldgate
# 10   City of London                           16167          Aldgate
# 11   City of London                           16167          Aldgate
# 12   City of London                           16167          Aldgate
# 13   City of London                           16167          Aldgate
# 14   City of London                           16167          Aldgate
# 15   City of London                           16167          Aldgate
# 16   City of London                           16167          Aldgate
# 17   City of London                           16167          Aldgate
# 18   City of London                           16167          Aldgate
# 19   City of London                           16167          Aldgate
# 20   City of London                           16167          Aldgate
# 21   City of London                           16167          Aldgate
# 22   City of London                           16167          Aldgate
# 23   City of London                           16167          Aldgate
# 24   City of London                           16167          Aldgate
# 25   City of London                           16167          Aldgate
# 26   City of London                           16167          Aldgate
# 27   City of London                           16167          Aldgate
# 28   City of London                           16167          Aldgate
# 29   City of London                           16167          Aldgate
# ..                              ...             ...              ...
# 170  City of London                          136749  Bank / Monument
# 171  City of London                          136749  Bank / Monument
# 172  City of London                          136749  Bank / Monument
# 173  City of London                          136749  Bank / Monument
# 174  City of London                          136749  Bank / Monument
# 175  City of London                          136749  Bank / Monument
# 176  City of London                          136749  Bank / Monument
# 177  City of London                          136749  Bank / Monument
# 178  City of London                          136749  Bank / Monument
# 179  City of London                          136749  Bank / Monument
# 180  City of London                          136749  Bank / Monument
# 181  City of London                          136749  Bank / Monument
# 182  City of London                          136749  Bank / Monument
# 183  City of London                          136749  Bank / Monument
# 184  City of London                          136749  Bank / Monument
# 185  City of London                          136749  Bank / Monument
# 186  City of London                          136749  Bank / Monument
# 187  City of London                          136749  Bank / Monument
# 188  City of London                          136749  Bank / Monument
# 189  City of London                          136749  Bank / Monument
# 190  City of London                          136749  Bank / Monument
# 191  City of London                           20336         Barbican
# 192  City of London                           20336         Barbican
# 193  City of London                           20336         Barbican
# 194  City of London                           20336         Barbican
# 195  City of London                           20336         Barbican
# 196  City of London                           20336         Barbican
# 197  City of London                           20336         Barbican
# 198  City of London                           20336         Barbican
# 199  City of London                           20336         Barbican
#
#                                  address      categories  distance        lat  \
# 0                126 Whitechapel High St     Coffee Shop       210  51.514966
# 1                      9 Aldgate High St     Coffee Shop        34  51.513990
# 2                          90 Mansell St     Coffee Shop       413  51.511502
# 3                 83 Whitechapel High St     Coffee Shop       402  51.515919
# 4                             2 Leman St     Coffee Shop       248  51.515066
# 5           133, Whitechapel High Street     Coffee Shop       157  51.514746
# 6                      122 Leadenhall St     Coffee Shop       461  51.513736
# 7                         30 St Mary Axe     Coffee Shop       360  51.514643
# 8                                    NaN     Coffee Shop       320  51.512188
# 9                                    NaN     Coffee Shop       305  51.514543
# 10                       Lloyds Building            Café       498  51.513040
# 11                68 Whitechapel High St            Café       441  51.516040
# 12                     28-30 Houndsditch            Café       175  51.514685
# 13                      25 Fenchurch Ave     Coffee Shop       401  51.512664
# 14                         Units 4 and 5     Coffee Shop       453  51.518036
# 15                      121 Leman street  Sandwich Place       531  51.511762
# 16                                   NaN     Coffee Shop       477  51.511041
# 17                       Creechurch Lane     Coffee Shop       271  51.513495
# 18                  74 Commercial Street     Coffee Shop       463  51.518390
# 19                        15 St Mary Axe     Coffee Shop       399  51.514264
# 20                                   NaN     Coffee Shop       469  51.516279
# 21                       Fenchurch Place     Coffee Shop       407  51.511664
# 22                                   NaN            Café       434  51.514471
# 23                         1 Lime Street            Café       471  51.516775
# 24                                   NaN            Café       515  51.518884
# 25                     Leadenhall Market     Coffee Shop       571  51.513256
# 26         One Minster Court, Mincing Ln     Coffee Shop       563  51.510915
# 27                                   NaN     Coffee Shop       566  51.513711
# 28                        48-50 Minories     Coffee Shop       306  51.511556
# 29                      9 Whitechapel Rd     Coffee Shop       491  51.516307
# ..                                   ...             ...       ...        ...
# 170                                  NaN     Coffee Shop       437  51.511041
# 171                     14 Austin Friars     Coffee Shop       543  51.515677
# 172                                  NaN            Café       255  51.513068
# 173                                  NaN            Café       648  51.505115
# 174                    Leadenhall Market     Coffee Shop       331  51.513256
# 175                                  NaN     Coffee Shop       228  51.510491
# 176        One Minster Court, Mincing Ln     Coffee Shop       330  51.510915
# 177                    6 Copthall Avenue     Coffee Shop       586  51.516001
# 178       30 Gresham St, London EC2V 7PG            Café       658  51.514558
# 179                       15 St Mary Axe     Coffee Shop       519  51.514264
# 180                      Fenchurch Place     Coffee Shop       475  51.511664
# 181                                  NaN     Coffee Shop       522  51.506178
# 182                                  NaN     Coffee Shop       373  51.513711
# 183             Unit 5 The Retail Arcade     Coffee Shop       669  51.504796
# 184                   87 King William St     Coffee Shop       248  51.512707
# 185                          38 Walbrook     Coffee Shop       331  51.512619
# 186                         11 Eastcheap            Café       100  51.510819
# 187  St. Mary Aldermary Church courtyard            Café       545  51.512401
# 188                Unit 6, Hays Galleria     Coffee Shop       574  51.505897
# 189                   13-15 Old Broad St     Coffee Shop       446  51.514770
# 190                  23 Duke Street Hill            Café       540  51.505984
# 191                           Goswell Rd     Coffee Shop       323  51.523291
# 192                      46 Cowcross St.     Coffee Shop       493  51.519985
# 193                        70 St John St          Office       285  51.521542
# 194                   161a Whitecross St     Coffee Shop       469  51.523447
# 195                    47 Clerkenwell Rd            Café       489  51.522613
# 196      33-34 Chiswell Street, Moorgate     Coffee Shop       500  51.520911
# 197                                  NaN            Café       212  51.522311
# 198                       43 Cowcross St     Coffee Shop       484  51.520125
# 199                       20 Goswell Rd.     Coffee Shop       214  51.522321
#
#           lng                                     name postalCode
# 0   -0.072658                             Costa Coffee     E1 7PU
# 1   -0.075459                       Black Sheep Coffee   EC3N 1AH
# 2   -0.071572                             Costa Coffee     E1 8AL
# 3   -0.070309                           Exmouth Coffee     E1 7QX
# 4   -0.072126                       Black Sheep Coffee     E1 8FA
# 5   -0.073347    Department of Coffee & Social Affairs        NaN
# 6   -0.082098                       Black Sheep Coffee   EC3V 4AB
# 7   -0.080671          Notes Coffee Roaster & Wine Bar   EC3A 8EP
# 8   -0.078651                           Coffee Society   EC3M 4BR
# 9   -0.071105    Hyde Independent Specialty Coffee Bar     E1 8EN
# 10  -0.082411                       Lloyds Coffee Shop        NaN
# 11  -0.069781                     Aldgate Coffee House     E1 7PL
# 12  -0.077960                       Secret Frog Coffee        NaN
# 13  -0.080666                             Costa Coffee   EC3M 5BS
# 14  -0.078092                             Costa Coffee   EC2M 4AA
# 15  -0.069006                       Lemans Coffee Shop     E1 8EY
# 16  -0.079992                              Coffee Life        NaN
# 17  -0.079203                        Barros Coffee Bar        NaN
# 18  -0.074270                         Black Box Coffee         E1
# 19  -0.081268                             Costa Coffee   EC3A 8AH
# 20  -0.069523                          Comrades Coffee     E1 1DU
# 21  -0.079575                               AMT Coffee   EC3R 7JP
# 22  -0.069240                Delices Coffee & Pastries        NaN
# 23  -0.081018                     Lloyd's Coffee House        NaN
# 24  -0.074446      Morson Coffee stand at Spitalfields        NaN
# 25  -0.083582                             Hatch coffee        NaN
# 26  -0.081540                              RoMo Coffee   EC3R 7AA
# 27  -0.083621                      Johnny's Coffee Bar        NaN
# 28  -0.075125                                Starbucks   EC3N 1JJ
# 29  -0.069179                                 Grounded     E1 1DU
# ..        ...                                      ...        ...
# 170 -0.079992                              Coffee Life        NaN
# 171 -0.085855                          Soho Coffee Co.   EC2N 2HE
# 172 -0.086819                   Carraways Coffee House        NaN
# 173 -0.084276                            Coffee Allans        NaN
# 174 -0.083582                             Hatch coffee        NaN
# 175 -0.083044                       Ray's Coffee Stand        NaN
# 176 -0.081540                              RoMo Coffee   EC3R 7AA
# 177 -0.087688                             Costa Coffee   EC2R 7DA
# 178 -0.093647                               v69 coffee   EC2V 7PG
# 179 -0.081268                             Costa Coffee   EC3A 8AH
# 180 -0.079575                               AMT Coffee   EC3R 7JP
# 181 -0.087579                           beanbag coffee        NaN
# 182 -0.083621                      Johnny's Coffee Bar        NaN
# 183 -0.086873                                Starbucks    SE1 9SG
# 184 -0.088153                                Starbucks   EC4N 7BJ
# 185 -0.090088                                Starbucks   EC4N 8BN
# 186 -0.084852                         Cheese & Peppers   EC3M 1BN
# 187 -0.093736                                     RoMo   EC4M 9BW
# 188 -0.083694                                Starbucks    SE1 2HD
# 189 -0.085338                                Starbucks   EC2N 1DW
# 190 -0.087331       My Tea Shop (My Tea & Coffee Shop)    SE1 2SW
# 191 -0.098308                             Costa Coffee        NaN
# 192 -0.104996                             Costa Coffee   EC1M 6BY
# 193 -0.101592                   Workshop Coffee Co. HQ   EC1M 4DT
# 194 -0.093207                               Fix Coffee   EC1Y 8JL
# 195 -0.103999                               EC1 Coffee   EC1M 5RS
# 196 -0.090723                     The Pink Coffee Cart   EC1Y 4SF
# 197 -0.098041                             Coffee Aroma   WC2H 7BX
# 198 -0.104879  Department of Coffee and Social Affairs   EC1M 6BY
# 199 -0.097606                       Coming Soon Coffee   EC1M 7AA
#
# [200 rows x 10 columns]

# %%
map_coffee = folium.Map(location=[latitude, longitude], zoom_start=15)
# add markers to map
for lat, lng, borough, neighborhood in zip(stationsDataZone_1_Total['Latitude'], stationsDataZone_1_Total['Longitude'], stationsDataZone_1_Total['Borough'], stationsDataZone_1_Total['Station Name']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_coffee)    
# add popular spots to the map as blue circle markers
for lat, lng in zip(CoffeeShop_data.lat, CoffeeShop_data.lng):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5, 
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
        ).add_to(map_coffee)

# display map
map_coffee
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Analysis of coffee shops distribution by Boroughs and tube stations

# %%
CoffeeShopXBorough = CoffeeShop_data.groupby(['Borough']).size().reset_index(name='CountCoffeeShops Borough')
CoffeeShopXBorough.sort_values(by='CountCoffeeShops Borough', ascending=False)
# Out:
#                           Borough  CountCoffeeShops Borough
# 8  Westminster                                          579
# 1  City of London                                       353
# 0  Camden                                               258
# 7  Tower Hamlets                                         67
# 6  Southwark                                             58
# 3  Islington                                             46
# 5  Lambeth                                               46
# 4  Kensington & Chelsea                                  38
# 2  Hackney                                               28

# %%
CoffeeShopXStation = CoffeeShop_data.groupby(['Borough','Station Name']).size().reset_index(name='CountCoffeeShops Station')
CoffeeShopXStation = CoffeeShopXStation.merge(CoffeeShopXBorough, left_on='Borough', right_on='Borough',suffixes=('_left', '_right'))
#CoffeeShopXStation.sort_values(by='CountCoffeeShops Borough', ascending=False).head(200)
stationsListToOptimize = stationsDataZone_1_Total.loc[stationsDataZone_1_Total['ID']!=166]
stationsListToOptimize.reset_index(drop=True, inplace=True)
stationsListToOptimize = stationsListToOptimize.merge(CoffeeShopXStation, left_on='Station Name', right_on='Station Name',suffixes=('_left', '_right'))
stationsListToOptimize['TrafficIndex'] = stationsListToOptimize['Number exiting'].div(stationsListToOptimize['CountCoffeeShops Station'],axis=0)
#stationsListToOptimize.sort_values(by='TrafficIndex', ascending=False).head(200)
print('The median traffic index for existing coffee shops in Zone 1 is:', stationsListToOptimize['TrafficIndex'].median())
stationsListFinal = stationsListToOptimize.loc[stationsListToOptimize['TrafficIndex']>stationsListToOptimize['TrafficIndex'].median()]
stationsListFinal.reset_index(drop=True, inplace=True)
stationsListFinal.rename(columns={"Borough_right": "Borough"}, inplace=True)
stationsListFinal.drop(columns=['Borough_left','Time Period'], axis = 1,inplace=True)
print('The final number of stations selected in Zone 1 is:', len(stationsListFinal))
stationsListFinal.sort_values(by='TrafficIndex', ascending=False).head(200)
# Out:
# The median traffic index for existing coffee shops in Zone 1 is: 1362.5059523809523
# The final number of stations selected in Zone 1 is: 29
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/pandas/core/frame.py:3027: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      ID  Latitude  Longitude              Station Name  Station Number  Zone  \
# 25  273   51.4965    -0.1447                  Victoria           741.0   1.0
# 23  236   51.4941    -0.1738          South Kensington           708.0   1.0
# 26  279   51.5036    -0.1143                  Waterloo           747.0   1.0
# 7   107   51.5067    -0.1428                Green Park           590.0   1.0
# 10  145   51.5308    -0.1238  King's Cross St. Pancras           625.0   1.0
# 22  229   51.4924    -0.1565             Sloane Square           702.0   1.0
# 27  285   51.5010    -0.1254               Westminster           761.0   1.0
# 20  198   51.4893    -0.1334                   Pimlico           776.0   1.0
# 18  193   51.5154    -0.1755                Paddington           670.0   1.0
# 14  157   51.5052    -0.0864             London Bridge           635.0   1.0
# 5    89   51.5282    -0.1337                    Euston           574.0   1.0
# 6    99   51.4945    -0.1829           Gloucester Road           583.0   1.0
# 8   122   51.5009    -0.1925    High Street Kensington           605.0   1.0
# 17  192   51.5150    -0.1415             Oxford Circus           669.0   1.0
# 1    11   51.5226    -0.1571              Baker Street           511.0   1.0
# 13  156   51.5178    -0.0823          Liverpool Street           634.0   1.0
# 0     7   51.5322    -0.1058                     Angel           507.0   1.0
# 11  146   51.5015    -0.1607             Knightsbridge           626.0   1.0
# 4    87   51.5074    -0.1223                Embankment           542.0   1.0
# 24  248   51.4994    -0.1335          St. James's Park           695.0   1.0
# 3    28   51.5142    -0.1494               Bond Street           524.0   1.0
# 28  233   51.5010    -0.1052                 Southwark           784.0   1.0
# 9   133   51.5027    -0.1527          Hyde Park Corner           614.0   1.0
# 2    13   51.5133    -0.0886           Bank / Monument           513.0   1.0
# 21  208   51.5107    -0.1877                 Queensway           681.0   1.0
# 12  149   51.5119    -0.1756            Lancaster Gate           629.0   1.0
# 16  188   51.5263    -0.0873                Old Street           665.0   1.0
# 19  197   51.5098    -0.1342         Piccadilly Circus           674.0   1.0
# 15  163   51.5225    -0.1631                Marylebone           641.0   1.0
#
#     Number exiting                         Borough  CountCoffeeShops Station  \
# 25          127176  Westminster                                           19
# 23           50662  Kensington & Chelsea                                   9
# 26          147683  Lambeth                                               27
# 7            69611  Westminster                                           13
# 10          147949  Camden                                                29
# 22           27657  Kensington & Chelsea                                   6
# 27           40204  Westminster                                            9
# 20           17389  Westminster                                            4
# 18           81691  Westminster                                           19
# 14          108319  Southwark                                             26
# 5            64272  Camden                                                17
# 6            20619  Kensington & Chelsea                                   6
# 8            20350  Kensington & Chelsea                                   6
# 17          138502  Westminster                                           49
# 1            45436  Westminster                                           19
# 13          113087  City of London                                        48
# 0            30631  Islington                                             14
# 11           23486  Kensington & Chelsea                                  11
# 4            35515  Westminster                                           18
# 24           25461  Westminster                                           13
# 3            61940  Westminster                                           35
# 28           28717  Southwark                                             17
# 9             8198  Westminster                                            5
# 2           136749  City of London                                        88
# 21           12396  Westminster                                            8
# 12            9284  Westminster                                            6
# 16           42022  Hackney                                               28
# 19           57840  Westminster                                           39
# 15           22220  Westminster                                           16
#
#     CountCoffeeShops Borough  TrafficIndex
# 25                       579   6693.473684
# 23                        38   5629.111111
# 26                        46   5469.740741
# 7                        579   5354.692308
# 10                       258   5101.689655
# 22                        38   4609.500000
# 27                       579   4467.111111
# 20                       579   4347.250000
# 18                       579   4299.526316
# 14                        58   4166.115385
# 5                        258   3780.705882
# 6                         38   3436.500000
# 8                         38   3391.666667
# 17                       579   2826.571429
# 1                        579   2391.368421
# 13                       353   2355.979167
# 0                         46   2187.928571
# 11                        38   2135.090909
# 4                        579   1973.055556
# 24                       579   1958.538462
# 3                        579   1769.714286
# 28                        58   1689.235294
# 9                        579   1639.600000
# 2                        353   1553.965909
# 21                       579   1549.500000
# 12                       579   1547.333333
# 16                        28   1500.785714
# 19                       579   1483.076923
# 15                       579   1388.750000

# %%
selectedStations = stationsListFinal
print('Number of stations selected by potential traffic :', len(stationsListFinal))
selectedStations.head(29)
# Out:
# Number of stations selected by potential traffic : 29
#      ID  Latitude  Longitude              Station Name  Station Number  Zone  \
# 0     7   51.5322    -0.1058                     Angel           507.0   1.0
# 1    11   51.5226    -0.1571              Baker Street           511.0   1.0
# 2    13   51.5133    -0.0886           Bank / Monument           513.0   1.0
# 3    28   51.5142    -0.1494               Bond Street           524.0   1.0
# 4    87   51.5074    -0.1223                Embankment           542.0   1.0
# 5    89   51.5282    -0.1337                    Euston           574.0   1.0
# 6    99   51.4945    -0.1829           Gloucester Road           583.0   1.0
# 7   107   51.5067    -0.1428                Green Park           590.0   1.0
# 8   122   51.5009    -0.1925    High Street Kensington           605.0   1.0
# 9   133   51.5027    -0.1527          Hyde Park Corner           614.0   1.0
# 10  145   51.5308    -0.1238  King's Cross St. Pancras           625.0   1.0
# 11  146   51.5015    -0.1607             Knightsbridge           626.0   1.0
# 12  149   51.5119    -0.1756            Lancaster Gate           629.0   1.0
# 13  156   51.5178    -0.0823          Liverpool Street           634.0   1.0
# 14  157   51.5052    -0.0864             London Bridge           635.0   1.0
# 15  163   51.5225    -0.1631                Marylebone           641.0   1.0
# 16  188   51.5263    -0.0873                Old Street           665.0   1.0
# 17  192   51.5150    -0.1415             Oxford Circus           669.0   1.0
# 18  193   51.5154    -0.1755                Paddington           670.0   1.0
# 19  197   51.5098    -0.1342         Piccadilly Circus           674.0   1.0
# 20  198   51.4893    -0.1334                   Pimlico           776.0   1.0
# 21  208   51.5107    -0.1877                 Queensway           681.0   1.0
# 22  229   51.4924    -0.1565             Sloane Square           702.0   1.0
# 23  236   51.4941    -0.1738          South Kensington           708.0   1.0
# 24  248   51.4994    -0.1335          St. James's Park           695.0   1.0
# 25  273   51.4965    -0.1447                  Victoria           741.0   1.0
# 26  279   51.5036    -0.1143                  Waterloo           747.0   1.0
# 27  285   51.5010    -0.1254               Westminster           761.0   1.0
# 28  233   51.5010    -0.1052                 Southwark           784.0   1.0
#
#     Number exiting                         Borough  CountCoffeeShops Station  \
# 0            30631  Islington                                             14
# 1            45436  Westminster                                           19
# 2           136749  City of London                                        88
# 3            61940  Westminster                                           35
# 4            35515  Westminster                                           18
# 5            64272  Camden                                                17
# 6            20619  Kensington & Chelsea                                   6
# 7            69611  Westminster                                           13
# 8            20350  Kensington & Chelsea                                   6
# 9             8198  Westminster                                            5
# 10          147949  Camden                                                29
# 11           23486  Kensington & Chelsea                                  11
# 12            9284  Westminster                                            6
# 13          113087  City of London                                        48
# 14          108319  Southwark                                             26
# 15           22220  Westminster                                           16
# 16           42022  Hackney                                               28
# 17          138502  Westminster                                           49
# 18           81691  Westminster                                           19
# 19           57840  Westminster                                           39
# 20           17389  Westminster                                            4
# 21           12396  Westminster                                            8
# 22           27657  Kensington & Chelsea                                   6
# 23           50662  Kensington & Chelsea                                   9
# 24           25461  Westminster                                           13
# 25          127176  Westminster                                           19
# 26          147683  Lambeth                                               27
# 27           40204  Westminster                                            9
# 28           28717  Southwark                                             17
#
#     CountCoffeeShops Borough  TrafficIndex
# 0                         46   2187.928571
# 1                        579   2391.368421
# 2                        353   1553.965909
# 3                        579   1769.714286
# 4                        579   1973.055556
# 5                        258   3780.705882
# 6                         38   3436.500000
# 7                        579   5354.692308
# 8                         38   3391.666667
# 9                        579   1639.600000
# 10                       258   5101.689655
# 11                        38   2135.090909
# 12                       579   1547.333333
# 13                       353   2355.979167
# 14                        58   4166.115385
# 15                       579   1388.750000
# 16                        28   1500.785714
# 17                       579   2826.571429
# 18                       579   4299.526316
# 19                       579   1483.076923
# 20                       579   4347.250000
# 21                       579   1549.500000
# 22                        38   4609.500000
# 23                        38   5629.111111
# 24                       579   1958.538462
# 25                       579   6693.473684
# 26                        46   5469.740741
# 27                       579   4467.111111
# 28                        58   1689.235294

# %% [markdown]
# # Use decision optimization

# %% [markdown]
# ## Step 1: Import the docplex package¶

# %%
import sys
import docplex.mp

# %% [markdown]
# ## Step 2: Model the data

# %% [markdown]
# The data for this problem is quite simple: it is composed of the list of tube station selected from the previous section and their geographical locations.

# %% [markdown]
# ## Step 3: Prepare the data

# %% [markdown]
# We need to collect the list of identified tube station locations and keep their names, latitudes, and longitudes.

# %%
# Store longitude, latitude and street crossing name of each public library location.
class XPoint(object):
    def __init__(self, x, y):
        self.x = x
        self.y = y
    def __str__(self):
        return "P(%g_%g)" % (self.x, self.y)

class NamedPoint(XPoint):
    def __init__(self, name, x, y):
        XPoint.__init__(self, x, y)
        self.name = name
    def __str__(self):
        return self.name

# %% [markdown]
# Define how to compute the earth distance between 2 points
# To easily compute distance between 2 points, we use the Python package geopy

# %%
try:
    import geopy.distance
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip install geopy 
    else:
        # !pip install --user geopy

# %%
# Simple distance computation between 2 locations.
from geopy.distance import great_circle
 
def get_distance(p1, p2):
    return great_circle((p1.y, p1.x), (p2.y, p2.x)).miles

# %%
listCoffeeLocation = []
for latitude, longitude, name in zip(selectedStations['Latitude'], selectedStations['Longitude'],selectedStations['Station Name']):
    cp = NamedPoint(name, longitude, latitude)
    listCoffeeLocation.append(cp)

# %%
print("There are %d suitable tube location in Zone1" % (len(listCoffeeLocation)))
# Out:
# There are 29 suitable tube location in Zone1

# %%
nb_shops = 5
print("We would like to open %d coffee shops" % nb_shops)
# Out:
# We would like to open 5 coffee shops

# %% [markdown]
# #### Validate the data by displaying them
# We will use the folium library to display a map with markers.

# %%
try:
    import folium
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip install folium 
    else:
        # !pip install folium

# %%
import folium
map_osm = folium.Map(location=[latitude, longitude], zoom_start=13)
for station in listCoffeeLocation:
    lt = station.y
    lg = station.x
    folium.Marker([lt, lg]).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# After running the above code, the data is displayed but it is impossible to determine where to ideally open the coffee shops by just looking at the map.
#
# Let's set up DOcplex to write and solve an optimization model that will help us determine where to locate the coffee shops in an optimal way.

# %% [markdown]
# ### Set up the prescriptive model

# %%
from docplex.mp.environment import Environment
env = Environment()
env.print_information()
# Out:
# * system is: Linux 64bit
# * Python is present, version is 3.5.5
# * docplex is present, version is (2, 8, 125)
# * CPLEX wrapper is present, version is 12.8.0.0, located at: /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages

# %% [markdown]
# Create the DOcplex model The model contains all the business constraints and defines the objective.

# %%
from docplex.mp.model import Model

mdl = Model("coffee shops")
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/docplex/mp/model.py:14: Warning: These editions of DOcplex and CPLEX for Watson Studio are in beta.
#   warnings.warn('These editions of DOcplex and CPLEX for Watson Studio are in beta.', Warning)

# %% [markdown]
# Define the decision variables

# %%
BIGNUM = 999999999

# Ensure unique points
listCoffeeLocation = set(listCoffeeLocation)
# For simplicity, let's consider that coffee shops candidate locations are the same as station locations.
# That is: any station location can also be selected as a coffee shop.
coffeeshop_locations = listCoffeeLocation

# Decision vars
# Binary vars indicating which coffee shop locations will be actually selected
coffeeshop_vars = mdl.binary_var_dict(coffeeshop_locations, name="is_coffeeshop")
#
# Binary vars representing the "assigned" libraries for each coffee shop
link_vars = mdl.binary_var_matrix(coffeeshop_locations, listCoffeeLocation, "link")

# %% [markdown]
# Express the business constraints First constraint: if the distance is suspect, it needs to be excluded from the problem.

# %%
for c_loc in coffeeshop_locations:
    for b in listCoffeeLocation:
        if get_distance(c_loc, b) >= BIGNUM:
            mdl.add_constraint(link_vars[c_loc, b] == 0, "ct_forbid_{0!s}_{1!s}".format(c_loc, b))

# %% [markdown]
# Second constraint: each station must be linked to a coffee shop that is open.

# %%
mdl.add_constraints(link_vars[c_loc, b] <= coffeeshop_vars[c_loc]
                   for b in listCoffeeLocation
                   for c_loc in coffeeshop_locations)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 870
#    - binary=870, integer=0, continuous=0
#  - number of constraints: 841
#    - linear=841
#  - parameters: defaults

# %% [markdown]
# Third constraint: each station is linked to exactly one coffee shop.

# %%
mdl.add_constraints(mdl.sum(link_vars[c_loc, b] for c_loc in coffeeshop_locations) == 1
                   for b in listCoffeeLocation)
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 870
#    - binary=870, integer=0, continuous=0
#  - number of constraints: 870
#    - linear=870
#  - parameters: defaults

# %% [markdown]
# Fourth constraint: there is a fixed number of coffee shops to open.

# %%
# Total nb of open coffee shops
mdl.add_constraint(mdl.sum(coffeeshop_vars[c_loc] for c_loc in coffeeshop_locations) == nb_shops)

# Print model information
mdl.print_information()
# Out:
# Model: coffee shops
#  - number of variables: 870
#    - binary=870, integer=0, continuous=0
#  - number of constraints: 871
#    - linear=871
#  - parameters: defaults

# %% [markdown]
# Express the objective The objective is to minimize the total distance from stations to coffee shops so that a commuter always gets to our coffee shop easily.

# %%
# Minimize total distance from points to hubs
total_distance = mdl.sum(link_vars[c_loc, b] * get_distance(c_loc, b) for c_loc in coffeeshop_locations for b in listCoffeeLocation)
mdl.minimize(total_distance)

# %% [markdown]
# Solve with the Decision Optimization solve service Solve the model.

# %%
print("# coffee shops locations = %d" % len(coffeeshop_locations))
print("# coffee shops           = %d" % nb_shops)

assert mdl.solve(), "!!! Solve of the model fails"
# Out:
# # coffee shops locations = 29
# # coffee shops           = 5

# %% [markdown]
# ### Investigate the solution and then run an example analysis

# %% [markdown]
# The solution can be analyzed by displaying the location of the coffee shops on a map.

# %%
total_distance = mdl.objective_value
open_coffeeshops = [c_loc for c_loc in coffeeshop_locations if coffeeshop_vars[c_loc].solution_value == 1]
not_coffeeshops = [c_loc for c_loc in coffeeshop_locations if c_loc not in open_coffeeshops]
edges = [(c_loc, b) for b in listCoffeeLocation for c_loc in coffeeshop_locations if int(link_vars[c_loc, b]) == 1]

print("Total distance = %g" % total_distance)
print("# coffee shops  = {0}".format(len(open_coffeeshops)))
for c in open_coffeeshops:
    print("new coffee shop: {0!s}".format(c))
# Out:
# Total distance = 16.9946
# # coffee shops  = 5
# new coffee shop: Hyde Park Corner
# new coffee shop: Lancaster Gate
# new coffee shop: Westminster
# new coffee shop: King's Cross St. Pancras
# new coffee shop: Bank / Monument

# %% [markdown]
# Displaying the solution Coffee shops are highlighted in red.

# %%
import folium
map_osm = folium.Map(location=[51.5098, -0.1342], zoom_start=13)
for coffeeshop in open_coffeeshops:
    lt = coffeeshop.y
    lg = coffeeshop.x
    folium.Marker([lt, lg], icon=folium.Icon(color='red',icon='info-sign')).add_to(map_osm)
    
for b in listCoffeeLocation:
    if b not in open_coffeeshops:
        lt = b.y
        lg = b.x
        folium.Marker([lt, lg]).add_to(map_osm)
    

for (c, b) in edges:
    coordinates = [[c.y, c.x], [b.y, b.x]]
    map_osm.add_child(folium.PolyLine(coordinates, color='#FF0000', weight=5))

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # END
